# %%
"""This file contains the LangGraph Agent/workflow and interactions with the LLM."""
import os
import sys
# IMPORTANT : Ajouter le dossier backend au chemin Python
current_dir = os.path.dirname(os.path.abspath(''))
# Si on est dans agents/, remonter au parent (backend/)
if current_dir.endswith('agents'):
    parent_dir = os.path.dirname(current_dir)
else:
    # Si on est déjà dans backend/
    parent_dir = current_dir

sys.path.insert(0, parent_dir)

from typing import (
    Any,
    AsyncGenerator,
    Dict,
    Literal,
    Optional,
    List,
)
import asyncio
from motor.motor_asyncio import AsyncIOMotorClient

from typing_extensions import Annotated


from langchain_core.messages import (
    BaseMessage,
    ToolMessage,
    HumanMessage,
    AIMessage,
    convert_to_openai_messages,
    AIMessageChunk
)
from langchain_openai import ChatOpenAI

from langgraph.checkpoint.mongodb.aio import AsyncMongoDBSaver
from langgraph.prebuilt import ToolNode, tools_condition, InjectedState
from langgraph.graph import (
    END,
    START,
    StateGraph,
)
from langgraph.graph.state import CompiledStateGraph
from langgraph.types import StateSnapshot, Command, interrupt
from openai import OpenAIError
from services.search_service import SearchService
from fastapi.responses import StreamingResponse


import random
import logging
from langchain_core.tools import tool
from langchain_core.callbacks.manager import AsyncCallbackManager
from langchain_core.callbacks.base import AsyncCallbackHandler
from agents.tools.searchFacebook import SearchFacebook
from agents.tools.googlePlaces import GooglePlaces
from schemas import (
    GraphState,
    Message,
    RangeFilter,
)
from utils import dump_messages, prepare_messages
import json
from database_manager import mongo_manager
from database import mongo_db
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Configuration du logging
logger = logging.getLogger(__name__)

# Initialisation des outils
search_service = None
google_places = None
facebook = None

try:
    google_places = GooglePlaces()
    logger.info("GooglePlaces initialisé avec succès")
except Exception as e:
    logger.error(f"Erreur initialisation GooglePlaces: {e}")
    google_places = None

try:
    search_service = SearchService()
    logger.info("SearchService initialisé avec succès")
except Exception as e:
    logger.error(f"Erreur initialisation SearchService: {e}")
    search_service = None

try:
    facebook = SearchFacebook()
    logger.info("SearchFacebook initialisé avec succès")
except Exception as e:
    logger.error(f"Erreur initialisation SearchFacebook: {e}")
    facebook = None
# Out:
# initialisation du scraper facebook...

# %%
@tool
async def search_listing(
    city: str,
    min_bedrooms: int,
    max_bedrooms: int,
    min_price: int,
    max_price: int,
    location_near: Optional[list] = None,
    enrich_top_k: int = 3,
    session_id: Annotated[str, InjectedState("session_id")] = None
):
    """Search listings in listings website according to user preferences.

    Args:
        city: The city to search in
        min_bedrooms: Minimum bedrooms wanted
        max_bedrooms: Maximum bedrooms wanted
        min_price: Minimum price wanted
        max_price: Maximum price wanted
        location_near: Optional nearby locations in a list
        enrich_top_k: Number of listings to enrich with page details
        state: The state of the graph

    """
    logger.info(f"=== DÉBUT SEARCH_LISTING ===")
    logger.info(
        f"Paramètres reçus: city={city}, min_bedrooms={min_bedrooms}, max_bedrooms={max_bedrooms}, min_price={min_price}, max_price={max_price}, location_near={location_near}, enrich_top_k={enrich_top_k}"
    )

    try:
        if not search_service:
            logger.error("SearchService non initialisé")
            return {"error": "Service de recherche non disponible"}


        search_params = {
            "city": city,
            "min_bedrooms": min_bedrooms,
            "max_bedrooms": max_bedrooms,
            "min_price": min_price,
            "max_price": max_price,
            "location_near": location_near,
            "enrich_top_k": enrich_top_k,
        }

        user_ip = "127.0.0.1"
        
        

        result = await search_service.search_listings(
            search_params,
            user_ip,
            session_id,
        )

        #logger.info(f"Résultat SearchService: {result}")

        if result["status"] == "cached":
            logger.info("✅ Cache hit - Réponse instantanée")
            return {
                "status": "success",
                "data": result["data"],
                "source": "cache",
                "cached_at": result["cached_at"],
            }
        elif result["status"] == "queued":
            # �� JOB EN QUEUE : Non-bloquant !
            logger.info("�� Job mis en queue - Non-bloquant")
            return {
                "status": "queued",
                "job_id": result["job_id"],
                "message": result["message"],
                "estimated_wait": result["estimated_wait"],
                "source": "queue",
            }
        elif result["status"] == "processing":
            # ⏳ JOB EN COURS : Déjà lancé
            logger.info("⏳ Job déjà en cours")
            return {
                "status": "processing",
                "job_id": result["job_id"],
                "estimated_wait": result["estimated_wait"],
                "source": "existing_job",
            }

        elif result["status"] == "completed":
            # ✅ JOB TERMINÉ : Résultat disponible
            logger.info("✅ Job terminé - Résultat disponible")
            return {
                "status": "success",
                "data": result["data"],
                "source": "completed_job",
            }
        elif result["status"] == "rate_limited":
            # 🚫 RATE LIMIT : Trop de requêtes
            logger.warning("�� Rate limit dépassé")
            return {
                "status": "rate_limited",
                "message": result["message"],
                "retry_after": result["retry_after"],
            }

        else:
            # ❌ ERREUR : Gestion d'erreur
            logger.error(f"❌ Statut inattendu: {result}")
            return {
                "status": "error",
                "message": result.get("message", "Erreur inconnue"),
                "error": result.get("error", "Erreur non spécifiée"),
            }

    except Exception as e:
        logger.error(f"Erreur dans search_listing: {e}")
        logger.error(f"Traceback:", exc_info=True)
        return {
            "status": "error",
            "message": "Erreur lors de la recherche",
            "error": str(e),
        }
    finally:
        logger.info("=== FIN SEARCH_LISTING ===")


@tool
async def check_job_status(job_id: str):
    """Check the status of a job.

    Args:
        job_id: The ID of the job to check

    Returns:
        dict: The status of the job
    """
    try:
        if not search_service:
            logger.error("SearchService non initialisé")
            return {"error": "Service de recherche non disponible"}

        result = await search_service.get_job_status(job_id)
        logger.info(f"Statut du job {job_id}: {result}")
        return result
    except Exception as e:
        logger.error(f"Erreur dans check_job_status: {e}")
        return {
            "status": "error",
            "message": "Erreur lors de la vérification du statut du job",
            "error": str(e),
        }

# %%
class IanGraph:
    def __init__(self):
        self.llm = ChatOpenAI(
            model="gpt-4o-mini",
            api_key=os.getenv("OPENAI_API_KEY"),
            max_tokens=1000,
        ).bind_tools([search_listing])
        # Utiliser le manager au lieu d'une connexion directe
        self._client = mongo_manager.get_async_client()
        self._graph: Optional[CompiledStateGraph] = None
        self._checkpointer: Optional[AsyncMongoDBSaver] = None
       
    def __process_message(self, messages: list[BaseMessage]) -> list[Message]:
        openai_style_messages = convert_to_openai_messages(messages)
        return [
            Message(**message)
            for message in openai_style_messages
            if message["role"] in ["assistant", "user"] and message["content"]
        ]
        
    def serialise_ai_message_chunk(self, chunk: dict) -> str:
        if(isinstance(chunk, AIMessageChunk)):
            return chunk.content
        else:
            raise TypeError(f"Expected AIMessageChunk, got {type(chunk).__name__}")
        
    async def get_stream_response(self, messages: list[Message], session_id: str):
        
        config = {
            "configurable": {"thread_id": session_id},
            "metadata": {
                "debug": False,
            },
        }
        
        try:
            # ✅ Créer le checkpointer et compiler le graph pour cette invocation
            async with AsyncMongoDBSaver.from_conn_string(
                os.getenv("MONGO_URI"),
                db_name=os.getenv("MONGO_DB"),
                collection_name="checkpointers",
            ) as checkpointer:

                # Créer le graph builder si pas encore fait
                if not hasattr(self, "_graph_builder"):
                    self._graph_builder = await self._create_graph_builder()

                # Compiler le graph avec le checkpointer pour cette invocation
                graph_with_checkpointer = self._graph_builder.compile(
                    checkpointer=checkpointer
                )
                
                events = graph_with_checkpointer.astream_events(
                    {"messages": dump_messages(messages), "session_id": session_id},
                    config=config,
                )
                async for event in events:
                    event_type = event["event"]
                    
                    # 🔍 DEBUG : Voir la structure de l'event
                    print(f"Event reçu: {event}\n")
                    print(f"Event type: {event_type}\n")
                    print(f"Event data keys: {event.get('data', {}).keys()}")
                    
                    # ✅ APRÈS (sécurisé) - Vérifier AVANT d'accéder
                    if event_type in ("on_llm_stream","on_chat_model_stream") and "chunk" in event.get("data", {}):
                        chunk_content = self.serialise_ai_message_chunk(event["data"]["chunk"])
                        payload = {"type": "content", "content": chunk_content}
                        yield f"data: {json.dumps(payload)}\n\n"
                    # elif event_type == "on_chat_model_stream":
                        
                    elif event_type == "on_tool_start":
                        tools_call = event["data"]["output"].tool_calls if hasattr(event["data"]["output"], "tool_calls") else []
                        print(f"Tool start event: {event}")
                    elif event_type in ("end","on_chat_model_end") or (
                        event_type == "on_chain_end" and event.get("name") == "LangGraph"
                    ):
                        yield f"data: {json.dumps({'type': '[DONE]'})}\n\n"
                        break
                    
 

        except Exception as e:
            logger.error(f"error_getting_response: {e}")
            raise e
      

    async def _create_graph_builder(self):
        """Create the graph builder (without compilation)."""
        try:
            tool_node = ToolNode([search_listing])
            logger.info("ToolNode initialisé avec succès")
        except Exception as e:
            logger.error(f"Erreur initialisation ToolNode: {e}")
            logger.error(f"Traceback:", exc_info=True)
            raise

        try:
            graph_builder = StateGraph(GraphState)
            logger.info("StateGraph initialisé avec succès")
        except Exception as e:
            logger.error(f"Erreur initialisation StateGraph: {e}")
            logger.error(f"Traceback:", exc_info=True)
            raise
        

        logger.info("Ajout des nodes au graph...")
        try:
            graph_builder.add_node("chatbot", self._chat)
            # graph_builder.add_node("human_verif", human_pref_validator)
            graph_builder.add_node("tools", tool_node)
            logger.info("Nodes ajoutés avec succès")
        except Exception as e:
            logger.error(f"Erreur ajout des nodes: {e}")
            logger.error(f"Traceback:", exc_info=True)
            raise

        logger.info("Ajout des edges au graph...")
        try:
            graph_builder.add_edge(START, "chatbot")
            graph_builder.add_conditional_edges("chatbot", tools_condition)
            graph_builder.add_edge("tools", "chatbot")
            logger.info("Edges ajoutés avec succès")
        except Exception as e:
            logger.error(f"Erreur ajout des edges: {e}")
            logger.error(f"Traceback:", exc_info=True)
            raise

        return graph_builder

    async def _chat(self, state: GraphState) -> dict:

        logger.info(f"=== DÉBUT CHATBOT ===")
        
        if hasattr(state, "session_id"):
            logger.info(f"Session_id récupéré: {state.session_id}")
        else:
            logger.warning("Impossible de récupérer le session_id, utilisation du fallback")
            state.session_id = None

        try:
            
            logger.info(f"lenght of state.messages: {len(state.messages)}")

            messages = prepare_messages(
                state.messages,
                self.llm,
                "You are a helpful assistant that can search for listings and provide information about them.",
            )

            logger.info("Message ajouté au state")
            logger.info("=== FIN CHATBOT ===")
            generated_state = {
                "messages": [await self.llm.ainvoke(dump_messages(messages))]
            }
            return generated_state

        except Exception as e:
            logger.error(f"Erreur dans chatbot: {e}")
            logger.error(f"Traceback:", exc_info=True)
            raise

# %%
ian = IanGraph()
    
config = {
    "configurable": {"thread_id":"66bd41ade6e37be2ef4b4fc2"},
        "metadata": {
            "debug": False,
            },
        }
        
async for event in ian.get_stream_response(
    [HumanMessage(content="Je cherche un appartement à Paris avec 2 chambres et un balcon min 1000$ max 5000$ et max 4 chambres")]   
,
"66bd41ade6e37be2ef4b4fc2"):
    print(event)
# Out:
# Event reçu: {'event': 'on_chain_start', 'data': {'input': {'messages': [{'content': 'Je cherche un appartement à Paris avec 2 chambres et un balcon min 1000$ max 5000$ et max 4 chambres', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': None, 'example': False}], 'session_id': '66bd41ade6e37be2ef4b4fc2'}}, 'name': 'LangGraph', 'tags': [], 'run_id': '219040f6-53b2-45e4-b5e9-dce509857c04', 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2'}, 'parent_ids': []}
#
# Event type: on_chain_start
#
# Event data keys: dict_keys(['input'])
# Event reçu: {'event': 'on_chain_start', 'data': {'input': GraphState(messages=[HumanMessage(content='Bonjour', additional_kwargs={}, response_metadata={}, id='86b046b5-cdf4-4dfd-a99c-5445c07c9292'), AIMessage(content="Bonjour ! Comment puis-je vous aider aujourd'hui ?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 197, 'total_tokens': 208, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CA8pXbHpjjMaZkpJ2KnYzE0uNMxFj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--230adb55-7aa7-45fa-9dae-d7578542170c-0', usage_metadata={'input_tokens': 197, 'output_tokens': 11, 'total_tokens': 208, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Je cherche un appart', additional_kwargs={}, response_metadata={}, id='44727ef4-67f7-4ea8-a518-1314acaf7172'), HumanMessage(content='oui', additional_kwargs={}, response_metadata={}, id='ce97f473-f70d-47de-9844-02874b5d3e93'), HumanMessage(content='Je cherche un appart', additional_kwargs={}, response_metadata={}, id='384445ad-24f3-4143-bf96-127ce1d2a9dd'), AIMessage(content="D'accord ! Pour vous aider à trouver un appartement, pourriez-vous me donner quelques détails supplémentaires ? \n\n- Dans quelle ville cherchez-vous ?\n- Combien de chambres souhaitez-vous ?\n- Quel est votre budget minimum et maximum ?\n- Y a-t-il des emplacements spécifiques à proximité que vous préférez ? \n\nAvec ces informations, je pourrai effectuer une recherche pour vous.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 232, 'total_tokens': 307, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CA8wRZXznjP0XkYKZOM0JGxD4Dm2Q', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6e3e6661-9151-4e0e-9ec8-03c7d079f969-0', usage_metadata={'input_tokens': 232, 'output_tokens': 75, 'total_tokens': 307, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='d60149fd-f663-488b-b914-d7926d77a0c4'), HumanMessage(content='allo', additional_kwargs={}, response_metadata={}, id='9fc22a59-d17e-498a-b8e3-d2aff85d8ed3'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 320, 'total_tokens': 330, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CAIymJXpkQU6ZxlVvNkSnwOm4OJ57', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--7afe3b7f-5937-477a-b607-eda4221c300d-0', usage_metadata={'input_tokens': 320, 'output_tokens': 10, 'total_tokens': 330, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Je cherche un appart', additional_kwargs={}, response_metadata={}, id='11e3ce43-4e73-444a-b342-039f28cc9309'), HumanMessage(content='ok 2 chambres', additional_kwargs={}, response_metadata={}, id='4baf4159-2f7a-4ceb-aaed-00ee083e8568'), HumanMessage(content='Montreal', additional_kw ...
#
# Event type: on_chain_start
#
# Event data keys: dict_keys(['input'])
# Event reçu: {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[SystemMessage(content='You are a helpful assistant that can search for listings and provide information about them.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Bonjour', additional_kwargs={}, response_metadata={}, id='86b046b5-cdf4-4dfd-a99c-5445c07c9292'), AIMessage(content="Bonjour ! Comment puis-je vous aider aujourd'hui ?", additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 197, 'output_tokens': 11, 'total_tokens': 208, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 197, 'total_tokens': 208, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CA8pXbHpjjMaZkpJ2KnYzE0uNMxFj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--230adb55-7aa7-45fa-9dae-d7578542170c-0'), HumanMessage(content='Je cherche un appart', additional_kwargs={}, response_metadata={}, id='44727ef4-67f7-4ea8-a518-1314acaf7172'), HumanMessage(content='oui', additional_kwargs={}, response_metadata={}, id='ce97f473-f70d-47de-9844-02874b5d3e93'), HumanMessage(content='Je cherche un appart', additional_kwargs={}, response_metadata={}, id='384445ad-24f3-4143-bf96-127ce1d2a9dd'), AIMessage(content="D'accord ! Pour vous aider à trouver un appartement, pourriez-vous me donner quelques détails supplémentaires ? \n\n- Dans quelle ville cherchez-vous ?\n- Combien de chambres souhaitez-vous ?\n- Quel est votre budget minimum et maximum ?\n- Y a-t-il des emplacements spécifiques à proximité que vous préférez ? \n\nAvec ces informations, je pourrai effectuer une recherche pour vous.", additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 232, 'output_tokens': 75, 'total_tokens': 307, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 232, 'total_tokens': 307, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CA8wRZXznjP0XkYKZOM0JGxD4Dm2Q', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6e3e6661-9151-4e0e-9ec8-03c7d079f969-0'), HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='d60149fd-f663-488b-b914-d7926d77a0c4'), HumanMessage(content='allo', additional_kwargs={}, response_metadata={}, id='9fc22a59-d17e-498a-b8e3-d2aff85d8ed3'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 320, 'output_tokens': 10, 'total_tokens': 330, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 320, 'total_tokens': 330, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CAIymJXpkQU6ZxlVvNkSnwOm4OJ57', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--7afe3b7f-5937-477a-b607-eda4221c300d-0'), HumanMessage(content='Je cherche un appart', additional_ ...
#
# Event type: on_chat_model_start
#
# Event data keys: dict_keys(['input'])
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_jgilBsCbZ8wnNlvqC13cMtgP', 'function': {'arguments': '', 'name': 'search_listing'}, 'type': 'function'}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', tool_calls=[{'name': 'search_listing', 'args': {}, 'id': 'call_jgilBsCbZ8wnNlvqC13cMtgP', 'type': 'tool_call'}], tool_call_chunks=[{'name': 'search_listing', 'args': '', 'id': 'call_jgilBsCbZ8wnNlvqC13cMtgP', 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '{"', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', tool_calls=[{'name': '', 'args': {}, 'id': None, 'type': 'tool_call'}], tool_call_chunks=[{'name': None, 'args': '{"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'city', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': 'city', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'city', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '":"', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '":"', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '":"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'Paris', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': 'Paris', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'Paris', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '","', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '","', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '","', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'min', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': 'min', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'min', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '_b', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '_b', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '_b', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'ed', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': 'ed', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'ed', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'rooms', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': 'rooms', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'rooms', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '":', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '":', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '":', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '2', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '2', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '2', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': ',"', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': ',"', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': ',"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'max', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': 'max', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'max', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '_b', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '_b', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '_b', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'ed', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': 'ed', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'ed', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'rooms', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': 'rooms', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'rooms', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '":', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '":', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '":', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '4', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '4', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '4', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': ',"', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': ',"', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': ',"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'min', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': 'min', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'min', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '_price', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '_price', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '_price', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '":', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '":', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '":', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '100', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '100', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '100', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '0', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '0', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '0', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': ',"', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': ',"', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': ',"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'max', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': 'max', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'max', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '_price', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '_price', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '_price', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '":', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '":', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '":', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '500', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '500', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '500', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '0', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '0', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '0', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '}', 'name': None}, 'type': None}]}, response_metadata={}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', invalid_tool_calls=[{'name': None, 'args': '}', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '}', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_51db84afab', 'service_tier': 'default'}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379')}, 'run_id': 'c4452cfb-37f8-4fc0-89e2-5857699ee379', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 28, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'checkpoint_ns': 'chatbot:6d769bf8-f840-4d20-3946-9b919a62e858', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['219040f6-53b2-45e4-b5e9-dce509857c04', 'ce453f02-385b-4b22-b3b3-1e4dd625f382']}
#
# Event type: on_chat_model_stream
#
# Event data keys: dict_keys(['chunk'])
# data: {"type": "content", "content": ""}
#
#
# Event reçu: {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_jgilBsCbZ8wnNlvqC13cMtgP', 'function': {'arguments': '{"city":"Paris","min_bedrooms":2,"max_bedrooms":4,"min_price":1000,"max_price":5000}', 'name': 'search_listing'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_51db84afab', 'service_tier': 'default'}, id='run--c4452cfb-37f8-4fc0-89e2-5857699ee379', tool_calls=[{'name': 'search_listing', 'args': {'city': 'Paris', 'min_bedrooms': 2, 'max_bedrooms': 4, 'min_price': 1000, 'max_price': 5000}, 'id': 'call_jgilBsCbZ8wnNlvqC13cMtgP', 'type': 'tool_call'}]), 'input': {'messages': [[SystemMessage(content='You are a helpful assistant that can search for listings and provide information about them.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Bonjour', additional_kwargs={}, response_metadata={}, id='86b046b5-cdf4-4dfd-a99c-5445c07c9292'), AIMessage(content="Bonjour ! Comment puis-je vous aider aujourd'hui ?", additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 197, 'output_tokens': 11, 'total_tokens': 208, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 197, 'total_tokens': 208, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CA8pXbHpjjMaZkpJ2KnYzE0uNMxFj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--230adb55-7aa7-45fa-9dae-d7578542170c-0'), HumanMessage(content='Je cherche un appart', additional_kwargs={}, response_metadata={}, id='44727ef4-67f7-4ea8-a518-1314acaf7172'), HumanMessage(content='oui', additional_kwargs={}, response_metadata={}, id='ce97f473-f70d-47de-9844-02874b5d3e93'), HumanMessage(content='Je cherche un appart', additional_kwargs={}, response_metadata={}, id='384445ad-24f3-4143-bf96-127ce1d2a9dd'), AIMessage(content="D'accord ! Pour vous aider à trouver un appartement, pourriez-vous me donner quelques détails supplémentaires ? \n\n- Dans quelle ville cherchez-vous ?\n- Combien de chambres souhaitez-vous ?\n- Quel est votre budget minimum et maximum ?\n- Y a-t-il des emplacements spécifiques à proximité que vous préférez ? \n\nAvec ces informations, je pourrai effectuer une recherche pour vous.", additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 232, 'output_tokens': 75, 'total_tokens': 307, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 232, 'total_tokens': 307, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CA8wRZXznjP0XkYKZOM0JGxD4Dm2Q', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6e3e6661-9151-4e0e-9ec8-03c7d079f969-0'), HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='d60149fd-f663-488b-b914-d7926d77a0c4'), HumanMessage(content='allo', additional_kwargs={}, response_metadata={}, id='9fc22a59-d17e-498a-b8e3-d2aff85d8ed3'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 320, 'output_tokens': 10, 'total_tokens': 330, 'input_token_details': {'audio': 0, 'cache_read': 0 ...
#
# Event type: on_chat_model_end
#
# Event data keys: dict_keys(['output', 'input'])
# data: {"type": "[DONE]"}
