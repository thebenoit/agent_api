# %%
"""This file contains the LangGraph Agent/workflow and interactions with the LLM."""
import os
import sys
# IMPORTANT : Ajouter le dossier backend au chemin Python
current_dir = os.path.dirname(os.path.abspath(''))
# Si on est dans agents/, remonter au parent (backend/)
if current_dir.endswith('agents'):
    parent_dir = os.path.dirname(current_dir)
else:
    # Si on est déjà dans backend/
    parent_dir = current_dir

sys.path.insert(0, parent_dir)

from typing import (
    Any,
    AsyncGenerator,
    Dict,
    Literal,
    Optional,
    List,
)
import asyncio
from motor.motor_asyncio import AsyncIOMotorClient

from typing_extensions import Annotated


from langchain_core.messages import (
    BaseMessage,
    ToolMessage,
    HumanMessage,
    AIMessage,
    convert_to_openai_messages,
)
from langchain_openai import ChatOpenAI

from langgraph.checkpoint.mongodb.aio import AsyncMongoDBSaver
from langgraph.prebuilt import ToolNode, tools_condition, InjectedState
from langgraph.graph import (
    END,
    START,
    StateGraph,
)
from langgraph.graph.state import CompiledStateGraph
from langgraph.types import StateSnapshot, Command, interrupt
from openai import OpenAIError
from services.search_service import SearchService
from fastapi.responses import StreamingResponse


import random
import logging
from langchain_core.tools import tool
from langchain_core.callbacks.manager import AsyncCallbackManager
from langchain_core.callbacks.base import AsyncCallbackHandler
from agents.tools.searchFacebook import SearchFacebook
from agents.tools.googlePlaces import GooglePlaces
from schemas import (
    GraphState,
    Message,
    RangeFilter,
)
from utils import dump_messages, prepare_messages
from database_manager import mongo_manager
from database import mongo_db
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Configuration du logging
logger = logging.getLogger(__name__)

# Initialisation des outils
search_service = None
google_places = None
facebook = None

try:
    google_places = GooglePlaces()
    logger.info("GooglePlaces initialisé avec succès")
except Exception as e:
    logger.error(f"Erreur initialisation GooglePlaces: {e}")
    google_places = None

try:
    search_service = SearchService()
    logger.info("SearchService initialisé avec succès")
except Exception as e:
    logger.error(f"Erreur initialisation SearchService: {e}")
    search_service = None

try:
    facebook = SearchFacebook()
    logger.info("SearchFacebook initialisé avec succès")
except Exception as e:
    logger.error(f"Erreur initialisation SearchFacebook: {e}")
    facebook = None
# Out:
# initialisation du scraper facebook...

# %%
@tool
async def search_listing(
    city: str,
    min_bedrooms: int,
    max_bedrooms: int,
    min_price: int,
    max_price: int,
    location_near: Optional[list] = None,
    enrich_top_k: int = 3,
    session_id: Annotated[str, InjectedState("session_id")] = None
):
    """Search listings in listings website according to user preferences.

    Args:
        city: The city to search in
        min_bedrooms: Minimum bedrooms wanted
        max_bedrooms: Maximum bedrooms wanted
        min_price: Minimum price wanted
        max_price: Maximum price wanted
        location_near: Optional nearby locations in a list
        enrich_top_k: Number of listings to enrich with page details
        state: The state of the graph

    """
    logger.info(f"=== DÉBUT SEARCH_LISTING ===")
    logger.info(
        f"Paramètres reçus: city={city}, min_bedrooms={min_bedrooms}, max_bedrooms={max_bedrooms}, min_price={min_price}, max_price={max_price}, location_near={location_near}, enrich_top_k={enrich_top_k}"
    )

    try:
        if not search_service:
            logger.error("SearchService non initialisé")
            return {"error": "Service de recherche non disponible"}


        search_params = {
            "city": city,
            "min_bedrooms": min_bedrooms,
            "max_bedrooms": max_bedrooms,
            "min_price": min_price,
            "max_price": max_price,
            "location_near": location_near,
            "enrich_top_k": enrich_top_k,
        }

        user_ip = "127.0.0.1"
        
        

        result = await search_service.search_listings(
            search_params,
            user_ip,
            session_id,
        )

        #logger.info(f"Résultat SearchService: {result}")

        if result["status"] == "cached":
            logger.info("✅ Cache hit - Réponse instantanée")
            return {
                "status": "success",
                "data": result["data"],
                "source": "cache",
                "cached_at": result["cached_at"],
            }
        elif result["status"] == "queued":
            # �� JOB EN QUEUE : Non-bloquant !
            logger.info("�� Job mis en queue - Non-bloquant")
            return {
                "status": "queued",
                "job_id": result["job_id"],
                "message": result["message"],
                "estimated_wait": result["estimated_wait"],
                "source": "queue",
            }
        elif result["status"] == "processing":
            # ⏳ JOB EN COURS : Déjà lancé
            logger.info("⏳ Job déjà en cours")
            return {
                "status": "processing",
                "job_id": result["job_id"],
                "estimated_wait": result["estimated_wait"],
                "source": "existing_job",
            }

        elif result["status"] == "completed":
            # ✅ JOB TERMINÉ : Résultat disponible
            logger.info("✅ Job terminé - Résultat disponible")
            return {
                "status": "success",
                "data": result["data"],
                "source": "completed_job",
            }
        elif result["status"] == "rate_limited":
            # 🚫 RATE LIMIT : Trop de requêtes
            logger.warning("�� Rate limit dépassé")
            return {
                "status": "rate_limited",
                "message": result["message"],
                "retry_after": result["retry_after"],
            }

        else:
            # ❌ ERREUR : Gestion d'erreur
            logger.error(f"❌ Statut inattendu: {result}")
            return {
                "status": "error",
                "message": result.get("message", "Erreur inconnue"),
                "error": result.get("error", "Erreur non spécifiée"),
            }

    except Exception as e:
        logger.error(f"Erreur dans search_listing: {e}")
        logger.error(f"Traceback:", exc_info=True)
        return {
            "status": "error",
            "message": "Erreur lors de la recherche",
            "error": str(e),
        }
    finally:
        logger.info("=== FIN SEARCH_LISTING ===")


@tool
async def check_job_status(job_id: str):
    """Check the status of a job.

    Args:
        job_id: The ID of the job to check

    Returns:
        dict: The status of the job
    """
    try:
        if not search_service:
            logger.error("SearchService non initialisé")
            return {"error": "Service de recherche non disponible"}

        result = await search_service.get_job_status(job_id)
        logger.info(f"Statut du job {job_id}: {result}")
        return result
    except Exception as e:
        logger.error(f"Erreur dans check_job_status: {e}")
        return {
            "status": "error",
            "message": "Erreur lors de la vérification du statut du job",
            "error": str(e),
        }

# %%
class IanGraph:
    def __init__(self):
        self.llm = ChatOpenAI(
            model="gpt-4o-mini",
            api_key=os.getenv("OPENAI_API_KEY"),
            max_tokens=1000,
        ).bind_tools([search_listing])
        # Utiliser le manager au lieu d'une connexion directe
        self._client = mongo_manager.get_async_client()
        self._graph: Optional[CompiledStateGraph] = None
        self._checkpointer: Optional[AsyncMongoDBSaver] = None
       
    def __process_message(self, messages: list[BaseMessage]) -> list[Message]:
        openai_style_messages = convert_to_openai_messages(messages)
        return [
            Message(**message)
            for message in openai_style_messages
            if message["role"] in ["assistant", "user"] and message["content"]
        ]
        
    def serialise_ai_message_chunk(self, chunk: dict) -> str:
        if(isinstance(chunk, AIMessageChunk)):
            return chunk.content
        else:
            raise TypeError(f"Expected AIMessageChunk, got {type(chunk).__name__}")
        
    async def get_stream_response(self, messages: list[Message], session_id: str):
        
        config = {
            "configurable": {"thread_id": session_id},
            "metadata": {
                "debug": False,
            },
        }
        
        try:
            # ✅ Créer le checkpointer et compiler le graph pour cette invocation
            async with AsyncMongoDBSaver.from_conn_string(
                os.getenv("MONGO_URI"),
                db_name=os.getenv("MONGO_DB"),
                collection_name="checkpointers",
            ) as checkpointer:

                # Créer le graph builder si pas encore fait
                if not hasattr(self, "_graph_builder"):
                    self._graph_builder = await self._create_graph_builder()

                # Compiler le graph avec le checkpointer pour cette invocation
                graph_with_checkpointer = self._graph_builder.compile(
                    checkpointer=checkpointer
                )
                
                events = graph_with_checkpointer.astream_events(
                    {"messages": dump_messages(messages), "session_id": session_id},
                    config=config,
                )
                   

                
                
                async for event in events:
                    event_type = event["event"]
                    
                    # 🔍 DEBUG : Voir la structure de l'event
                    print(f"Event reçu: {event}")
                    print(f"Event type: {event_type}")
                    print(f"Event data keys: {event.get('data', {}).keys()}")
                    
                    # ✅ APRÈS (sécurisé) - Vérifier AVANT d'accéder
                    if event_type == "on_llm_stream" and "chunk" in event.get("data", {}):
                        chunk_content = self.serialise_ai_message_chunk(event["data"]["chunk"])
                        safe_content = chunk_content.replace("","\\").replace("\n","\\n")
                        yield f"data: {{\"type\": \"content\",\"content\":\"{safe_content}\"}}n\n"
                    elif event_type == "on_chat_model_stream":
                        
                    elif event_type == "on_tool_start":
                        tools_call = event["data"]["output"].tool_calls if hasattr(event["data"]["output"], "tool_calls") else []
                        print(f"Tool start event: {event}")
                    elif event_type == "end":
                        yield "data: [DONE]\n\n"
                    else:
                        # 🔍 DEBUG : Voir les autres types d'events
                        print(f"Event ignoré de type: {event_type}")

        except Exception as e:
            logger.error(f"error_getting_response: {e}")
            raise e

    async def _create_graph_builder(self):
        """Create the graph builder (without compilation)."""
        try:
            tool_node = ToolNode([search_listing])
            logger.info("ToolNode initialisé avec succès")
        except Exception as e:
            logger.error(f"Erreur initialisation ToolNode: {e}")
            logger.error(f"Traceback:", exc_info=True)
            raise

        try:
            graph_builder = StateGraph(GraphState)
            logger.info("StateGraph initialisé avec succès")
        except Exception as e:
            logger.error(f"Erreur initialisation StateGraph: {e}")
            logger.error(f"Traceback:", exc_info=True)
            raise
        

        logger.info("Ajout des nodes au graph...")
        try:
            graph_builder.add_node("chatbot", self._chat)
            # graph_builder.add_node("human_verif", human_pref_validator)
            graph_builder.add_node("tools", tool_node)
            logger.info("Nodes ajoutés avec succès")
        except Exception as e:
            logger.error(f"Erreur ajout des nodes: {e}")
            logger.error(f"Traceback:", exc_info=True)
            raise

        logger.info("Ajout des edges au graph...")
        try:
            graph_builder.add_edge(START, "chatbot")
            graph_builder.add_conditional_edges("chatbot", tools_condition)
            graph_builder.add_edge("tools", "chatbot")
            logger.info("Edges ajoutés avec succès")
        except Exception as e:
            logger.error(f"Erreur ajout des edges: {e}")
            logger.error(f"Traceback:", exc_info=True)
            raise

        return graph_builder

    async def _chat(self, state: GraphState) -> dict:

        logger.info(f"=== DÉBUT CHATBOT ===")
        
        if hasattr(state, "session_id"):
            logger.info(f"Session_id récupéré: {state.session_id}")
        else:
            logger.warning("Impossible de récupérer le session_id, utilisation du fallback")
            state.session_id = None

        try:
            
            logger.info(f"lenght of state.messages: {len(state.messages)}")

            messages = prepare_messages(
                state.messages,
                self.llm,
                "You are a helpful assistant that can search for listings and provide information about them.",
            )

            logger.info("Message ajouté au state")
            logger.info("=== FIN CHATBOT ===")
            generated_state = {
                "messages": [await self.llm.ainvoke(dump_messages(messages))]
            }
            return generated_state

        except Exception as e:
            logger.error(f"Erreur dans chatbot: {e}")
            logger.error(f"Traceback:", exc_info=True)
            raise

# %%
ian = IanGraph()
    
config = {
    "configurable": {"thread_id":"66bd41ade6e37be2ef4b4fc2"},
        "metadata": {
            "debug": False,
            },
        }
        
async for event in ian.get_stream_response(
    [HumanMessage(content="tell me about communism")]   
,
"66bd41ade6e37be2ef4b4fc2"):
    print(event)
# Out:
# Event reçu: {'event': 'on_chain_start', 'data': {'input': {'messages': [{'content': 'Hello, how are you?', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': None, 'example': False}], 'session_id': '66bd41ade6e37be2ef4b4fc2'}}, 'name': 'LangGraph', 'tags': [], 'run_id': 'ab66a92f-f87d-428c-91e9-d30392cec571', 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2'}, 'parent_ids': []}
# Event type: on_chain_start
# Event data keys: dict_keys(['input'])
# Event ignoré de type: on_chain_start
# Event reçu: {'event': 'on_chain_start', 'data': {'input': GraphState(messages=[HumanMessage(content='allo', additional_kwargs={}, response_metadata={}, id='acaa26f7-ecd0-415f-a2cf-d27d5d864f91'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 197, 'total_tokens': 207, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9E6cuxeTXDmxBX6pDOQk6jr2YCX6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--f8b5a85c-a7ab-4ffb-9f11-a20984d50bcd-0', usage_metadata={'input_tokens': 197, 'output_tokens': 10, 'total_tokens': 207, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='je cherche un appart', additional_kwargs={}, response_metadata={}, id='1a96e90e-a924-4948-80cf-ee14c1b87749'), AIMessage(content="Bien sûr! Pourriez-vous me donner quelques détails supplémentaires? Voici ce dont j'ai besoin :\n\n1. Dans quelle ville recherchez-vous un appartement?\n2. Combien de chambres souhaitez-vous (minimum et maximum)?\n3. Quel est votre budget (prix minimum et maximum)?\n4. Y a-t-il des endroits spécifiques à proximité que vous aimeriez considérer?\n\nAvec ces informations, je pourrai vous aider à trouver des listings.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 218, 'total_tokens': 304, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9E6v4jl5GagBMBObWnSrAwWb0fFF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--a362660e-4b0a-43a7-a609-0cfd6bf15741-0', usage_metadata={'input_tokens': 218, 'output_tokens': 86, 'total_tokens': 304, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Mon nom est Jerry et je cherche un appart au sud de la france comme max 2500$', additional_kwargs={}, response_metadata={}, id='80b3a246-c177-48d0-aee2-c2c532e86d65'), AIMessage(content="Merci pour ces informations, Jerry! Pour vous aider au mieux, pourriez-vous préciser les points suivants :\n\n1. Quelle ville ou région spécifique au sud de la France recherchez-vous ?\n2. Combien de chambres souhaitez-vous dans l'appartement (minimum et maximum) ?\n3. Quel est le prix minimum que vous êtes prêt à payer ?\n\nAvec ces détails, je pourrai effectuer une recherche plus précise pour vous.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 331, 'total_tokens': 414, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9EAJcW5fXkr2DEo9t16YsMG3oFn2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--cad424e9-7802-4d6c-96e9-b073f4541d9c-0', usage_metadata={'input_tokens': 331, 'output_tokens': 83, 'total_tokens': 414, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='toi choisi un endroit du sud de la france max 2 chambres min 1000$', additional_kwargs={}, response_metadata={}, id='3ed12c82-1581-4bd1-8bdd-784c496eccea'), AIMessage(content='', additional_ ...
# Event type: on_chain_start
# Event data keys: dict_keys(['input'])
# Event ignoré de type: on_chain_start
# Event reçu: {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[SystemMessage(content='You are a helpful assistant that can search for listings and provide information about them.', additional_kwargs={}, response_metadata={}), HumanMessage(content='vasy', additional_kwargs={}, response_metadata={}, id='16404470-7920-43b3-b17d-03ec5b6909eb'), AIMessage(content='', additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 1146, 'output_tokens': 42, 'total_tokens': 1188, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'tool_calls': [{'id': 'call_kfHGgzQb7CRP0o6FKXv6xqI7', 'function': {'arguments': '{"city":"Nîmes","min_bedrooms":1,"max_bedrooms":2,"min_price":1000,"max_price":2500}', 'name': 'search_listing'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 1146, 'total_tokens': 1188, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9FeWfUgdUmlmWrBWA8QKEDjfKBpR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--f35b128f-c223-4d36-a80e-7dea4c4d80e4-0', tool_calls=[{'name': 'search_listing', 'args': {'city': 'Nîmes', 'min_bedrooms': 1, 'max_bedrooms': 2, 'min_price': 1000, 'max_price': 2500}, 'id': 'call_kfHGgzQb7CRP0o6FKXv6xqI7', 'type': 'tool_call'}]), ToolMessage(content='{"status": "queued", "job_id": "a7be533f-7fab-4d46-bfcf-dc20a4eaf193", "message": "Recherche en cours. Utilisez le job_id pour vérifier le statut.", "estimated_wait": "10-30 secondes", "source": "queue"}', name='search_listing', id='60d9121f-4207-4da8-944b-cf17d0a0daa1', tool_call_id='call_kfHGgzQb7CRP0o6FKXv6xqI7'), AIMessage(content="J'ai lancé une recherche d'appartements à Nîmes, avec 1 à 2 chambres et un budget entre 1000 $ et 2500 $. Attendez-vous à ce que cela prenne un peu de temps. Je vous informerai dès que j'aurai les résultats pour cette recherche !\n\nSi vous voulez que je continue à chercher dans d'autres villes, n'hésitez pas à me le faire savoir.", additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 1155, 'output_tokens': 86, 'total_tokens': 1241, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 1155, 'total_tokens': 1241, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9FeZgG6TmCYbOyhxpu79Ypyqu8EN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--be282880-3197-45ba-a7fa-e4b9445f6e7b-0'), HumanMessage(content='encore', additional_kwargs={}, response_metadata={}, id='c45b402f-212c-4a3b-9a1c-a73c1de8dd48'), AIMessage(content='', additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 1049, 'output_tokens': 41, 'total_tokens': 1090, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'tool_calls': [{'id': 'call_fgmG6G6nrv0LoBSYKJNHnRT4', 'function': {'arguments': '{"city":"Lyon","min_bedrooms":1,"max_bedrooms":2,"min_price":1000,"max_price":2500}', 'name': 'search_listing'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 1049, 'total_tokens': 1090, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_ ...
# Event type: on_chat_model_start
# Event data keys: dict_keys(['input'])
# Event ignoré de type: on_chat_model_start
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='Hello', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' again', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='!', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' I', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='’m', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' doing', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' well', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' thank', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='!', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' How', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' about', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='?', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' If', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=" there's", additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' anything', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' specific', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' need', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' help', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' or', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' if', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' any', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' questions', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' just', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' let', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' me', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' know', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='!', additional_kwargs={}, response_metadata={}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# Event reçu: {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')}, 'run_id': 'fd984766-db5d-4bb2-a927-1f6b6ffa7f2b', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': None, 'ls_max_tokens': 1000}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571', 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b']}
# Event type: on_chat_model_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chat_model_stream
# ...
# Event type: on_chain_start
# Event data keys: dict_keys(['input'])
# Event ignoré de type: on_chain_start
# Event reçu: {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': GraphState(messages=[HumanMessage(content='allo', additional_kwargs={}, response_metadata={}, id='acaa26f7-ecd0-415f-a2cf-d27d5d864f91'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 197, 'total_tokens': 207, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9E6cuxeTXDmxBX6pDOQk6jr2YCX6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--f8b5a85c-a7ab-4ffb-9f11-a20984d50bcd-0', usage_metadata={'input_tokens': 197, 'output_tokens': 10, 'total_tokens': 207, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='je cherche un appart', additional_kwargs={}, response_metadata={}, id='1a96e90e-a924-4948-80cf-ee14c1b87749'), AIMessage(content="Bien sûr! Pourriez-vous me donner quelques détails supplémentaires? Voici ce dont j'ai besoin :\n\n1. Dans quelle ville recherchez-vous un appartement?\n2. Combien de chambres souhaitez-vous (minimum et maximum)?\n3. Quel est votre budget (prix minimum et maximum)?\n4. Y a-t-il des endroits spécifiques à proximité que vous aimeriez considérer?\n\nAvec ces informations, je pourrai vous aider à trouver des listings.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 218, 'total_tokens': 304, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9E6v4jl5GagBMBObWnSrAwWb0fFF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--a362660e-4b0a-43a7-a609-0cfd6bf15741-0', usage_metadata={'input_tokens': 218, 'output_tokens': 86, 'total_tokens': 304, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Mon nom est Jerry et je cherche un appart au sud de la france comme max 2500$', additional_kwargs={}, response_metadata={}, id='80b3a246-c177-48d0-aee2-c2c532e86d65'), AIMessage(content="Merci pour ces informations, Jerry! Pour vous aider au mieux, pourriez-vous préciser les points suivants :\n\n1. Quelle ville ou région spécifique au sud de la France recherchez-vous ?\n2. Combien de chambres souhaitez-vous dans l'appartement (minimum et maximum) ?\n3. Quel est le prix minimum que vous êtes prêt à payer ?\n\nAvec ces détails, je pourrai effectuer une recherche plus précise pour vous.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 331, 'total_tokens': 414, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9EAJcW5fXkr2DEo9t16YsMG3oFn2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--cad424e9-7802-4d6c-96e9-b073f4541d9c-0', usage_metadata={'input_tokens': 331, 'output_tokens': 83, 'total_tokens': 414, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='toi choisi un endroit du sud de la france max 2 chambres min 1000$', additional_kwargs={}, response_metadata={}, id='3ed12c82-1581-4bd1-8bdd-784c496eccea'), AIMessage(cont ...
# Event type: on_chain_end
# Event data keys: dict_keys(['output', 'input'])
# Event ignoré de type: on_chain_end
# Event reçu: {'event': 'on_chain_stream', 'run_id': 'ab84d5d0-6d0b-40a8-a5ce-f440974ab99b', 'name': 'chatbot', 'tags': ['graph:step:56'], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2', 'langgraph_step': 56, 'langgraph_node': 'chatbot', 'langgraph_triggers': ('branch:to:chatbot',), 'langgraph_path': ('__pregel_pull', 'chatbot'), 'langgraph_checkpoint_ns': 'chatbot:f39e64b0-3642-3959-6500-a7a45c502240'}, 'data': {'chunk': {'messages': [AIMessage(content="Hello again! I’m doing well, thank you! How about you? If there's anything specific you need help with or if you have any questions, just let me know!", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')]}}, 'parent_ids': ['ab66a92f-f87d-428c-91e9-d30392cec571']}
# Event type: on_chain_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chain_stream
# Event reçu: {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content="Hello again! I’m doing well, thank you! How about you? If there's anything specific you need help with or if you have any questions, just let me know!", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')]}, 'input': GraphState(messages=[HumanMessage(content='allo', additional_kwargs={}, response_metadata={}, id='acaa26f7-ecd0-415f-a2cf-d27d5d864f91'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 197, 'total_tokens': 207, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9E6cuxeTXDmxBX6pDOQk6jr2YCX6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--f8b5a85c-a7ab-4ffb-9f11-a20984d50bcd-0', usage_metadata={'input_tokens': 197, 'output_tokens': 10, 'total_tokens': 207, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='je cherche un appart', additional_kwargs={}, response_metadata={}, id='1a96e90e-a924-4948-80cf-ee14c1b87749'), AIMessage(content="Bien sûr! Pourriez-vous me donner quelques détails supplémentaires? Voici ce dont j'ai besoin :\n\n1. Dans quelle ville recherchez-vous un appartement?\n2. Combien de chambres souhaitez-vous (minimum et maximum)?\n3. Quel est votre budget (prix minimum et maximum)?\n4. Y a-t-il des endroits spécifiques à proximité que vous aimeriez considérer?\n\nAvec ces informations, je pourrai vous aider à trouver des listings.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 218, 'total_tokens': 304, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9E6v4jl5GagBMBObWnSrAwWb0fFF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--a362660e-4b0a-43a7-a609-0cfd6bf15741-0', usage_metadata={'input_tokens': 218, 'output_tokens': 86, 'total_tokens': 304, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Mon nom est Jerry et je cherche un appart au sud de la france comme max 2500$', additional_kwargs={}, response_metadata={}, id='80b3a246-c177-48d0-aee2-c2c532e86d65'), AIMessage(content="Merci pour ces informations, Jerry! Pour vous aider au mieux, pourriez-vous préciser les points suivants :\n\n1. Quelle ville ou région spécifique au sud de la France recherchez-vous ?\n2. Combien de chambres souhaitez-vous dans l'appartement (minimum et maximum) ?\n3. Quel est le prix minimum que vous êtes prêt à payer ?\n\nAvec ces détails, je pourrai effectuer une recherche plus précise pour vous.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 331, 'total_tokens': 414, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9EAJcW5fXkr2DEo9t16YsMG3oFn2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--cad424e9-7802-4d6c-96e9- ...
# Event type: on_chain_end
# Event data keys: dict_keys(['output', 'input'])
# Event ignoré de type: on_chain_end
# Event reçu: {'event': 'on_chain_stream', 'run_id': 'ab66a92f-f87d-428c-91e9-d30392cec571', 'name': 'LangGraph', 'tags': [], 'metadata': {'debug': False, 'thread_id': '66bd41ade6e37be2ef4b4fc2'}, 'data': {'chunk': {'chatbot': {'messages': [AIMessage(content="Hello again! I’m doing well, thank you! How about you? If there's anything specific you need help with or if you have any questions, just let me know!", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--fd984766-db5d-4bb2-a927-1f6b6ffa7f2b')]}}}, 'parent_ids': []}
# Event type: on_chain_stream
# Event data keys: dict_keys(['chunk'])
# Event ignoré de type: on_chain_stream
# Event reçu: {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='allo', additional_kwargs={}, response_metadata={}, id='acaa26f7-ecd0-415f-a2cf-d27d5d864f91'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 197, 'total_tokens': 207, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9E6cuxeTXDmxBX6pDOQk6jr2YCX6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--f8b5a85c-a7ab-4ffb-9f11-a20984d50bcd-0', usage_metadata={'input_tokens': 197, 'output_tokens': 10, 'total_tokens': 207, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='je cherche un appart', additional_kwargs={}, response_metadata={}, id='1a96e90e-a924-4948-80cf-ee14c1b87749'), AIMessage(content="Bien sûr! Pourriez-vous me donner quelques détails supplémentaires? Voici ce dont j'ai besoin :\n\n1. Dans quelle ville recherchez-vous un appartement?\n2. Combien de chambres souhaitez-vous (minimum et maximum)?\n3. Quel est votre budget (prix minimum et maximum)?\n4. Y a-t-il des endroits spécifiques à proximité que vous aimeriez considérer?\n\nAvec ces informations, je pourrai vous aider à trouver des listings.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 218, 'total_tokens': 304, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9E6v4jl5GagBMBObWnSrAwWb0fFF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--a362660e-4b0a-43a7-a609-0cfd6bf15741-0', usage_metadata={'input_tokens': 218, 'output_tokens': 86, 'total_tokens': 304, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Mon nom est Jerry et je cherche un appart au sud de la france comme max 2500$', additional_kwargs={}, response_metadata={}, id='80b3a246-c177-48d0-aee2-c2c532e86d65'), AIMessage(content="Merci pour ces informations, Jerry! Pour vous aider au mieux, pourriez-vous préciser les points suivants :\n\n1. Quelle ville ou région spécifique au sud de la France recherchez-vous ?\n2. Combien de chambres souhaitez-vous dans l'appartement (minimum et maximum) ?\n3. Quel est le prix minimum que vous êtes prêt à payer ?\n\nAvec ces détails, je pourrai effectuer une recherche plus précise pour vous.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 331, 'total_tokens': 414, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C9EAJcW5fXkr2DEo9t16YsMG3oFn2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--cad424e9-7802-4d6c-96e9-b073f4541d9c-0', usage_metadata={'input_tokens': 331, 'output_tokens': 83, 'total_tokens': 414, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='toi choisi un endroit du sud de la france max 2 chambres min 1000$', additional_kwargs={}, response_metadata={}, id='3ed12c82-1581-4bd1-8bdd-784c496eccea'), AIMessage(content='', additional_kwargs={ ...
# Event type: on_chain_end
# Event data keys: dict_keys(['output'])
# Event ignoré de type: on_chain_end
